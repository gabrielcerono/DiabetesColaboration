# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk
from sklearn.ensemble import RandomForestRegressor
from random import randint
import xlrd

# %% [markdown]
# Gołębiewska J, Olechowski A, Wysocka-Mincewicz M, Odrobina D, Baszyńska-Wilk M, Groszek A, et al. (2017) Optical coherence tomography angiography vessel density in children with type 1 diabetes. PLoS ONE 12(10): e0186479. https://doi.org/10.1371/journal.pone.0186479
#
# Link to the dataset:  https://figshare.com/articles/dataset/Optical_coherence_tomography_angiography_vessel_density_in_children_with_type_1_diabetes/5520808

# %%
data = pd.read_excel('Gołębiewska2017.xlsx')
data.head()
# Out:
#    no   id     gr  group gender        age  diuration of the disese  \
# 0   1  107  Cases      0      F  11.726027                     1.00
# 1   2   21  Cases      0      M  17.295891                     1.00
# 2   3   21  Cases      0      M  17.295891                     1.00
# 3   4  163  Cases      0      M  17.306849                     1.07
# 4   5  163  Cases      0      M  17.306849                     1.07
#
#    age on onset of the disease  HbA1c mean level  microalbuminuria  ...  \
# 0                    10.726027               7.0              10.4  ...
# 1                    16.293150               6.6              12.5  ...
# 2                    16.293150               6.6              12.5  ...
# 3                    16.232876               8.3               NaN  ...
# 4                    16.232876               8.3               NaN  ...
#
#    diastolic blood preeasure    faz       wsvd       fsvd       psvd   ft  \
# 0                        NaN  0.187  57.040001  36.259998  58.830002  263
# 1                       60.0  0.301  56.240002  28.780001  58.840000  234
# 2                       60.0  0.303  51.520000  30.549999  53.580002  241
# 3                       61.0  0.047  55.799999  44.590000  56.580002  301
# 4                       61.0  0.047  55.799999  44.590000  56.580002  301
#
#    pft       wdvd       fdvd       pdvd
# 0  317  63.970001  32.849998  67.209999
# 1  324  61.540001  27.570000  64.980003
# 2  328  57.910000  27.770000  60.910000
# 3  342  60.529999  40.240002  62.410000
# 4  342  60.529999  40.240002  62.410000
#
# [5 rows x 23 columns]

# %%
len(data)
# Out:
# 168

# %%
data.columns
# Out:
# Index(['no', 'id', 'gr', 'group', 'gender', 'age', 'diuration of the disese',
#        'age on onset of the disease', 'HbA1c mean level', 'microalbuminuria',
#        'serum creatinine level',
#        'creatinine in the daily collection of urine ',
#        'systolic blood preasure', 'diastolic blood preeasure', 'faz', 'wsvd',
#        'fsvd', 'psvd', 'ft', 'pft', 'wdvd', 'fdvd', 'pdvd'],
#       dtype='object')

# %% [markdown]
# ### There is duplicated values, we can check them in the IDs.

# %%
data.drop_duplicates(subset=['id'], inplace = True)

# %%
data.tail()
# Out:
#       no   id        gr  group gender   age  diuration of the disese  \
# 160  161  224  Controls      1      F  13.0                      NaN
# 162  163  225  Controls      1      F  12.0                      NaN
# 164  165  226  Controls      1      M  11.0                      NaN
# 165  166  227  Controls      1      M  12.0                      NaN
# 166  167  228  Controls      1      F  13.0                      NaN
#
#      age on onset of the disease  HbA1c mean level  microalbuminuria  ...  \
# 160                          NaN               NaN               NaN  ...
# 162                          NaN               NaN               NaN  ...
# 164                          NaN               NaN               NaN  ...
# 165                          NaN               NaN               NaN  ...
# 166                          NaN               NaN               NaN  ...
#
#      diastolic blood preeasure    faz       wsvd       fsvd       psvd   ft  \
# 160                        NaN  0.284  53.700001  36.400002  55.320000  247
# 162                        NaN  0.275  52.250000  28.629999  55.189999  224
# 164                        NaN  0.054  57.349998  48.570000  57.580002  268
# 165                        NaN  0.261  49.270000  28.690001  51.840000  273
# 166                        NaN  0.204  56.400002  34.490002  58.099998  238
#
#      pft       wdvd       fdvd       pdvd
# 160  324  59.180000  31.219999  62.910000
# 162  318  59.709999  31.379999  62.340000
# 164  322  61.360001  32.869999  63.459999
# 165  338  58.980000  31.950001  62.889999
# 166  307  61.130001  33.119999  63.779999
#
# [5 rows x 23 columns]

# %% [markdown]
# There is a control group without diabetes. We should drop them. They have gr = cases, or group = 0. We are going to filter them based on group value.

# %%
data1 = data[data.group < 1]

# %%
data1.tail()
# Out:
#       no   id     gr  group gender        age  diuration of the disese  \
# 116  117   71  Cases      0      M  18.002739                    11.62
# 118  119  158  Cases      0      M  15.728767                    11.75
# 120  121  126  Cases      0      M  14.432877                    12.05
# 122  123  112  Cases      0      M  16.301371                    13.95
# 124  125  128  Cases      0      F  17.975342                    14.36
#
#      age on onset of the disease  HbA1c mean level  microalbuminuria  ...  \
# 116                     6.380822              8.01              2.44  ...
# 118                     3.978082              9.30              2.80  ...
# 120                     2.380822              7.20               NaN  ...
# 122                     2.353425              7.85              6.52  ...
# 124                     3.616438             11.60               NaN  ...
#
#      diastolic blood preeasure    faz       wsvd       fsvd       psvd   ft  \
# 116                       83.0  0.033  50.669998  39.889999  51.380001  243
# 118                        NaN    NaN  50.700001  43.240002  50.580002  279
# 120                       72.0  0.075  56.270000  42.669998  58.560001  283
# 122                       78.0  0.300  53.480000  31.350000  55.080002  252
# 124                       58.0  0.260  50.060001  27.610001  51.330002  253
#
#      pft       wdvd       fdvd       pdvd
# 116  297  56.959999  41.650002  57.910000
# 118  315  59.889999  42.759998  61.939999
# 120  323  61.869999  45.849998  63.730000
# 122  333  57.570000  27.350000  60.610001
# 124  316  57.099998  29.010000  59.130001
#
# [5 rows x 23 columns]

# %% [markdown]
# We have to map the gender Female = 0, Male 1

# %%
data1.replace({'F' : 0, 'M': 1}, inplace = True)
# Out:
# C:\Users\54226\Anaconda3\envs\python-ml-2020\lib\site-packages\pandas\core\frame.py:4278: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
data1.drop('gr', axis = 1, inplace = True)
# Out:
# C:\Users\54226\Anaconda3\envs\python-ml-2020\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
len(data1)
# Out:
# 64

# %% [markdown]
# ## Now we can fill the NAN values using the iterative imputer

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
iterative_imp = IterativeImputer()
iterative_imp.fit(data1)
# Out:
# IterativeImputer(add_indicator=False, estimator=None,
#                  imputation_order='ascending', initial_strategy='mean',
#                  max_iter=10, max_value=None, min_value=None,
#                  missing_values=nan, n_nearest_features=None, random_state=None,
#                  sample_posterior=False, skip_complete=False, tol=0.001,
#                  verbose=0)

# %%
data2 = iterative_imp.fit_transform(data1)
data2 = pd.DataFrame(data=data2, columns = data1.columns,)

# %%
data2.dtypes
# Out:
# no                                              float64
# id                                              float64
# group                                           float64
# gender                                          float64
# age                                             float64
# diuration of the disese                         float64
# age on onset of the disease                     float64
# HbA1c mean level                                float64
# microalbuminuria                                float64
# serum creatinine level                          float64
# creatinine in the daily collection of urine     float64
# systolic blood preasure                         float64
# diastolic blood preeasure                       float64
# faz                                             float64
# wsvd                                            float64
# fsvd                                            float64
# psvd                                            float64
# ft                                              float64
# pft                                             float64
# wdvd                                            float64
# fdvd                                            float64
# pdvd                                            float64
# dtype: object

# %%
## Random Forest can only takes float32.

# %%
data2 = data2.astype(np.float32)

# %%
data2.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## I will have to drop age of onset, as it leaks data

# %%
data2.drop(['age on onset of the disease','no', 'id', 'group'], axis=1, inplace = True)

# %%
data2
# Out:
#     group  gender        age  diuration of the disese  HbA1c mean level  \
# 0     0.0     0.0  11.726027                     1.00              7.00
# 1     0.0     1.0  17.295891                     1.00              6.60
# 2     0.0     1.0  17.306849                     1.07              8.30
# 3     0.0     1.0  17.734247                     1.21              6.65
# 4     0.0     0.0  14.495891                     1.38              9.65
# ..    ...     ...        ...                      ...               ...
# 59    0.0     1.0  18.002739                    11.62              8.01
# 60    0.0     1.0  15.728767                    11.75              9.30
# 61    0.0     1.0  14.432877                    12.05              7.20
# 62    0.0     1.0  16.301371                    13.95              7.85
# 63    0.0     0.0  17.975342                    14.36             11.60
#
#     microalbuminuria  serum creatinine level  \
# 0          10.400000                    0.50
# 1          12.500000                    0.78
# 2           8.913454                    0.83
# 3           2.800000                    0.86
# 4          14.600000                    0.73
# ..               ...                     ...
# 59          2.440000                    1.12
# 60          2.800000                    0.77
# 61          8.902466                    0.74
# 62          6.520000                    0.88
# 63          8.902369                    0.55
#
#     creatinine in the daily collection of urine   systolic blood preasure  \
# 0                                       1.113491               110.698364
# 1                                       1.720000               125.000000
# 2                                       1.432596               111.000000
# 3                                       1.900000               126.000000
# 4                                       1.000000               110.937111
# ..                                           ...                      ...
# 59                                      1.710000               127.000000
# 60                                      1.430000               112.059776
# 61                                      1.584216               118.000000
# 62                                      1.570000               113.000000
# 63                                      1.416021               110.000000
#
#     diastolic blood preeasure       faz       wsvd       fsvd       psvd  \
# 0                   66.657333  0.187000  57.040001  36.259998  58.830002
# 1                   60.000000  0.301000  56.240002  28.780001  58.840000
# 2                   61.000000  0.047000  55.799999  44.590000  56.580002
# 3                   70.000000  0.130000  53.590000  38.669998  55.040001
# 4                   68.609322  0.180000  55.160000  33.389999  57.049999
# ..                        ...       ...        ...        ...        ...
# 59                  83.000000  0.033000  50.669998  39.889999  51.380001
# 60                  69.879845  0.037795  50.700001  43.240002  50.580002
# 61                  72.000000  0.075000  56.270000  42.669998  58.560001
# 62                  78.000000  0.300000  53.480000  31.350000  55.080002
# 63                  58.000000  0.260000  50.060001  27.610001  51.330002
#
#        ft    pft       wdvd       fdvd       pdvd
# 0   263.0  317.0  63.970001  32.849998  67.209999
# 1   234.0  324.0  61.540001  27.570000  64.980003
# 2   301.0  342.0  60.529999  40.240002  62.410000
# 3   266.0  308.0  58.320000  34.990002  60.509998
# 4   254.0  326.0  59.990002  36.049999  62.480000
# ..    ...    ...        ...        ...        ...
# 59  243.0  297.0  56.959999  41.650002  57.910000
# 60  279.0  315.0  59.889999  42.759998  61.939999
# 61  283.0  323.0  61.869999  45.849998  63.730000
# 62  252.0  333.0  57.570000  27.350000  60.610001
# 63  253.0  316.0  57.099998  29.010000  59.130001
#
# [64 rows x 19 columns]

# %% [markdown]
# # Let's predict duration of diabetes

# %%
X = data2.drop('diuration of the disese', axis = 1)
y = data2['diuration of the disese']

# %%
from sklearn.model_selection import train_test_split
X, X_test, y, y_test = train_test_split(X, y, test_size=0.30, random_state= 42)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
#Sklearn does't have any function for SMAPE, so I wrote a function in python
#The function has 100%/n. I replaced 100% with 1, to have values between 0 and 1 in form of percentages.
#A is the real, while F is predicted.
def smape(a, f):
    return 1/len(a) * np.sum(2 * np.abs(f-a) / (np.abs(a) + np.abs(f)))

# %%
r2mean = []
SMAPEm = []
MSEm = []
RMSEm = []
MAEm= []

# %%
randomforest = RandomForestRegressor()

# %%
for x in range(1000): 
  X_train, X_test2, y_train, y_test2 = train_test_split(X, y, test_size=0.3)
  randomforest.fit(X_train, y_train)
  r2 = randomforest.score(X_test, y_test)
  y_pred = randomforest.predict(X_test)
  r2mean.append(r2)
  MAE = mean_absolute_error(y_test, y_pred)
  MAEm.append(MAE)
  MSE = mean_squared_error(y_test, y_pred)
  MSEm.append(MSE)
  RMSE = sqrt(mean_squared_error(y_test, y_pred))
  RMSEm.append(RMSE)
  SMAPE = smape(y_test, y_pred)
  SMAPEm.append(SMAPE)

# %%
Metrics = {'Metrics Means': ['R2', 'MSE', 'RMSE', 'SMAPE', 'MAE'],
           'Values': [np.mean(r2mean), np.mean(MSEm), np.mean(RMSEm), np.mean(SMAPEm), np.mean(MAE)]
           }

# %%
MetricsDF = pd.DataFrame.from_dict(Metrics)
MetricsDF
# Out:
#   Metrics Means     Values
# 0            R2  -0.196587
# 1           MSE  14.990118
# 2          RMSE   3.867010
# 3         SMAPE   0.604632
# 4           MAE   2.995295

# %%
# XGBOOST

# %%
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
# Out:
# C:\Users\54226\Anaconda3\envs\python-ml-2020\lib\site-packages\xgboost\__init__.py:29: FutureWarning: Python 3.5 support is deprecated; XGBoost will require Python 3.6+ in the near future. Consider upgrading to Python 3.6+.
#   FutureWarning)

# %%
xgb = XGBRegressor()

# %%
r2mean = []
SMAPEm = []
MSEm = []
RMSEm = []
MAEm= []

# %%
for x in range(1000): 
  X_train, X_test2, y_train, y_test2 = train_test_split(X, y, test_size=0.30)
  xgb.fit(X_train, y_train)
  r2 = xgb.score(X_test, y_test)
  y_pred = xgb.predict(X_test)
  r2mean.append(r2)
  MAE = mean_absolute_error(y_test, y_pred)
  MAEm.append(MAE)
  MSE = mean_squared_error(y_test, y_pred)
  MSEm.append(MSE)
  RMSE = sqrt(mean_squared_error(y_test, y_pred))
  RMSEm.append(RMSE)
  SMAPE = smape(y_test, y_pred)
  SMAPEm.append(SMAPE)

# %%
Metrics = {'Metrics Means': ['R2', 'MSE', 'RMSE', 'SMAPE', 'MAE'],
           'Values': [np.mean(r2mean), np.mean(MSEm), np.mean(RMSEm), np.mean(SMAPEm), np.mean(MAE)]
           }

# %%
MetricsDF = pd.DataFrame.from_dict(Metrics)
MetricsDF
# Out:
#   Metrics Means     Values
# 0            R2  -0.353176
# 1           MSE  16.951759
# 2          RMSE   4.101086
# 3         SMAPE   0.588523
# 4           MAE   3.113131
